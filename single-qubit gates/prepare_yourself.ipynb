# %%
import pennylane as qp
import numpy as np

# %%
# Codercise l.8.2 - State preparation 

dev = qp.device("default.qubit", wires=1)


@qp.qnode(dev)
def prepare_state():
    ##################
    # YOUR CODE HERE #
    ##################

    qp.H(wires=0)
    qp.T(wires=0)
    qp.T(wires=0)
    qp.T(wires=0)
    qp.T(wires=0)
    qp.T(wires=0)

    return qp.state()

# %%
# Codercise,  l.8.2 - State preparation revisited

dev = qp.device("default.qubit", wires=1)


@qp.qnode(dev)
def prepare_state():
    ##################
    # YOUR CODE HERE #
    ##################

    qp.RX(np.pi / 3, wires=0)

    return qp.state()

# %%
# Codercise l.8.4 - State preparation with Mottonen's method

v = np.array([0.52889389 - 0.14956775j, 0.67262317 + 0.49545818j])

##################
# YOUR CODE HERE #
##################

dev = qp.device("default.qubit", wires=1)

# CONSTRUCT A QNODE THAT USES qp.MottonenStatePreparation
# TO PREPARE A QUBIT IN STATE V, AND RETURN THE STATE

@qp.qnode(dev)
def prepare_state(state=v):

    qp.MottonenStatePreparation(state, wires=1)

    return qp.state()


# This will draw the quantum circuit and allow you to inspect the output gates
print(prepare_state(v))
print()
print(qp.draw(prepare_state, level="device")(v))
# Out:
# [0.52889389-0.14956775j 0.67262317+0.49545818j]
#
# 2: ──RY(1.98)──RZ(0.91)──GlobalPhase(-0.18)─┤  State
