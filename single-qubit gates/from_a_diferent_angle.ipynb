# %%
import pennylane as qp
import numpy as np

# %%
# Codercise - l.6.1 - Applying RX

dev = qp.device("default.qubit", wires=1)


@qp.qnode(dev)
def apply_rx_pi(state):
    """Apply an RX gate with an angle of pi to a particular basis state.

    Args:
        state (int): Either 0 or 1. If 1, initialize the qubit to state |1>
            before applying other operations.

    Returns:
        np.array[complex]: The state of the qubit after the operations.
    """
    if state == 1:
        qp.PauliX(wires=0)

    ##################
    # YOUR CODE HERE #
    ##################

    qp.RX(np.pi, wires=0)

    return qp.state()


print(apply_rx_pi(0))
print(apply_rx_pi(1))
# Out:
# [6.123234e-17+0.j 0.000000e+00-1.j]
# [0.000000e+00-1.j 6.123234e-17+0.j]

# %%
# Codercise l.6.2 - Plotting RX

dev = qp.device("default.qubit", wires=1)


@qp.qnode(dev)
def apply_rx(theta, state):
    """Apply an RX gate with an angle of theta to a particular basis state.

    Args:
        theta (float): A rotation angle.
        state (int): Either 0 or 1. If 1, initialize the qubit to state |1>
            before applying other operations.

    Returns:
        np.array[complex]: The state of the qubit after the operations.
    """
    if state == 1:
        qp.PauliX(wires=0)

    ##################
    # YOUR CODE HERE #
    ##################

    qp.RX(theta, wires=0)

    return qp.state()


# Code for plotting
angles = np.linspace(0, 4 * np.pi, 200)
output_states = np.array([apply_rx(t, 0) for t in angles])

plot = plotter(angles, output_states)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 34
#      31 angles = np.linspace(0, 4 * np.pi, 200)
#      32 output_states = np.array([apply_rx(t, 0) for t in angles])
# ---> 34 plot = plotter(angles, output_states)
#
# NameError: name 'plotter' is not defined

# %%
# Codercise l.6.3 - Plotting RY

dev = qp.device("default.qubit", wires=1)


@qp.qnode(dev)
def apply_rx(theta, state):
    """Apply an RX gate with an angle of theta to a particular basis state.

    Args:
        theta (float): A rotation angle.
        state (int): Either 0 or 1. If 1, initialize the qubit to state |1>
            before applying other operations.

    Returns:
        np.array[complex]: The state of the qubit after the operations.
    """
    if state == 1:
        qp.PauliX(wires=0)

    ##################
    # YOUR CODE HERE #
    ##################

    qp.RY(theta, wires=0)

    return qp.state()


# Code for plotting
angles = np.linspace(0, 4 * np.pi, 200)
output_states = np.array([apply_rx(t, 0) for t in angles])

plot = plotter(angles, output_states)
