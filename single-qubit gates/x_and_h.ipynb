# %%
import pennylane as qp
import numpy as np
# Out:
#      ┌───┐
# q_0: ┤ H ├
#      └───┘
# q_1: ─────

# %%
# Codercise l.4.1 - Flipping bits

dev = qp.device("default.qubit", wires=1)

U = np.array([[1, 1], [1, -1]]) / np.sqrt(2)


@qp.qnode(dev)
def varied_initial_state(state):
    """Complete the function such that we can apply the operation U to
    either |0> or |1> depending on the input argument flag.

    Args:
        state (int): Either 0 or 1. If 1, prepare the qubit in state |1>,
            otherwise, leave it in state 0.

    Returns:
        np.array[complex]: The state of the qubit after the operations.
    """

    if state == 1:
        qp.X(wires=0)

    qp.QubitUnitary(U, wires=0)

    return qp.state()

# %%
# Codercise l.4.2 - Uniform superpositions

dev = qp.device("default.qubit", wires=1)


@qp.qnode(dev)
def apply_hadamard():

    qp.Hadamard(wires=0)

    return qp.state()

apply_hadamard()
# Out:
# array([0.70710678+0.j, 0.70710678+0.j])

# %%
# Codercise l.4.3 - Combining X and H

dev = qp.device("default.qubit", wires=1)


@qp.qnode(dev)
def apply_hadamard_to_state(state):
    """Complete the function such that we can apply the Hadamard to
    either |0> or |1> depending on the input argument flag.

    Args:
        state (int): Either 0 or 1. If 1, prepare the qubit in state |1>,
            otherwise, leave it in state 0.

    Returns:
        np.array[complex]: The state of the qubit after the operations.
    """

    if state == 1:
        qp.X(wires=0)

    qp.Hadamard(wires=0)

    return qp.state()


print(apply_hadamard_to_state(0))
print(apply_hadamard_to_state(1))
# Out:
# [0.70710678+0.j 0.70710678+0.j]
# [ 0.70710678+0.j -0.70710678+0.j]

# %%
# Codercise l.4.4 - A QNode with X and H

dev = qp.device("default.qubit", wires=1)

@qp.qnode(dev)
def apply_hxh(state):

    if state == 1:
        qp.X(wires=0)

    qp.Hadamard(wires=0)
    qp.X(wires=0)
    qp.Hadamard(wires=0)

    return qp.state()

# Print your results
print(apply_hxh(0))
print(apply_hxh(1))
# Out:
# ---------------------------------------------------------------------------
# QuantumFunctionError                      Traceback (most recent call last)
# Cell In[8], line 16
#      13     qp.Hadamard(wires=0)
#      15 # Print your results
# ---> 16 print(apply_hxh(0))
#      17 print(apply_hxh(1))
#
# File c:\Users\blanc\AppData\Local\Programs\Python\Python313\Lib\site-packages\pennylane\workflow\qnode.py:880, in QNode.__call__(self, *args, **kwargs)
#     877     from ._capture_qnode import capture_qnode  # pylint: disable=import-outside-toplevel
#     879     return capture_qnode(self, *args, **kwargs)
# --> 880 return self._impl_call(*args, **kwargs)
#
# File c:\Users\blanc\AppData\Local\Programs\Python\Python313\Lib\site-packages\pennylane\workflow\qnode.py:848, in QNode._impl_call(self, *args, **kwargs)
#     846 def _impl_call(self, *args, **kwargs) -> Result:
#     847     # construct the tape
# --> 848     tape = self.construct(args, kwargs)
#     850     # Calculate the classical jacobians if necessary
#     851     self._compile_pipeline.set_classical_component(self, args, kwargs)
#
# File c:\Users\blanc\AppData\Local\Programs\Python\Python313\Lib\site-packages\pennylane\logging\decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File c:\Users\blanc\AppData\Local\Programs\Python\Python313\Lib\site-packages\pennylane\workflow\qnode.py:842, in QNode.construct(self, args, kwargs)
#     839 params = tape.get_parameters(trainable_only=False)
#     840 tape.trainable_params = math.get_trainable_indices(params)
# --> 842 _validate_qfunc_output(self._qfunc_output, tape.measurements)
#     843 self._tape = tape
#     844 return tape
#
# File c:\Users\blanc\AppData\Local\Programs\Python\Python313\Lib\site-packages\pennylane\workflow\qnode.py:154, in _validate_qfunc_output(qfunc_output, measurements)
#     145         measurement_processes = [
#     146             m.base.item()
#     147             for m in measurement_processes[0]
#     148             if isinstance(m.base.item(), qp.measurements.MeasurementProcess)
#     149         ]
#     151 if not measurement_processes or not all(
#     152     isinstance(m, qp.measurements.MeasurementProcess) for m in measurement_processes
#     153 ):
# --> 154     raise QuantumFunctionError(
#     155         "A quantum function must return either a single measurement, "
#     156         "or a nonempty sequence of measurements."
#     157     )
#     159 if any(ret is not m for ret, m in zip(measurement_processes, measurements, strict=True)):
#     160     raise QuantumFunctionError(
#     161         "All measurements must be returned in the order they are measured."
#     162     )
#
# QuantumFunctionError: A quantum function must return either a single measurement, or a nonempty sequence of measurements.
